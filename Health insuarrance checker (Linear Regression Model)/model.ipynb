# %%
import pandas as pd 
import numpy as np 
import seaborn as sns 
from sklearn import  linear_model

# %%
data = pd.read_csv('health_insurance_random.csv')
data
# Out:
#    Serial Number  Age  Policy Cost
# 0              1   21        24043
# 1              2   25        27730
# 2              3   30        36048
# 3              4   35        43912
# 4              5   40        54664
# 5              6   45        68223
# 6              7   50        84859
# 7              8   55        94663
# 8              9   58       108611
# 9             10   60       123459

# %%
sns.lmplot(x='Age', y='Policy Cost', data=data)

# %%
reg = linear_model.LinearRegression()

# %%
reg_age =reg.fit(data[['Age']],data['Policy Cost'])
reg_policy_cost = reg.fit(data[['Policy Cost']], data['Age'])

# %%
reg_age.predict([[23]])
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([15.85461051])

# %%
reg_policy_cost.predict([[86607.05820802]])
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([49.71611907])

# %%
from sklearn.model_selection  import train_test_split

# %%
x_train, x_test,y_train,y_test = train_test_split(data[['Age']], data['Policy Cost'])

# %%
x_train
# Out:
#    Age
# 7   55
# 8   58
# 4   40
# 0   21
# 3   35
# 5   45
# 1   25

# %%
x_test
# Out:
#    Age
# 2   30
# 9   60
# 6   50

# %%
y_train
# Out:
# 7     94663
# 8    108611
# 4     54664
# 0     24043
# 3     43912
# 5     68223
# 1     27730
# Name: Policy Cost, dtype: int64

# %%
y_test
# Out:
# 2     36048
# 9    123459
# 6     84859
# Name: Policy Cost, dtype: int64

# %%
lr = linear_model.LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
lr.predict(x_test)
# Out:
# array([ 37934.84579214, 105892.27164215,  83239.79635881])

# %%
lr.score(x_test,y_test)
# Out:
# 0.9179794136930841
