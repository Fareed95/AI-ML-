# %%
from sklearn.datasets import load_iris
import pandas as pd 
import numpy as np
import seaborn as sns

# %%
data = pd.read_csv('iris_data.csv')
data
# Out:
#      sepal length  sepal width  petal length  petal width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
y = data[['species']].values
y
# Out:
# array([['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
#        ['setosa'],
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
labelencoder =  LabelEncoder()
data['species'] = labelencoder.fit_transform(y)
data
# Out:
# c:\Users\Admin\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\preprocessing\_label.py:114: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
#      sepal length  sepal width  petal length  petal width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test, y_train,y_test = train_test_split(data[['sepal length','sepal width','petal length','petal width']],data['species'],test_size=0.2)

# %%
len(x_train)
# Out:
# 120

# %%
len(x_test)
# Out:
# 30

# %%
len(y_train)
# Out:
# 120

# %%
len(y_test)
# Out:
# 30

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
lr.predict(x_test)
# Out:
# array([0, 1, 2, 1, 0, 1, 1, 0, 1, 1, 0, 0, 2, 2, 1, 2, 1, 1, 0, 0, 1, 2,
#        0, 2, 2, 2, 0, 0, 2, 2])

# %%
lr.score(x_test,y_test)
# Out:
# 0.9333333333333333

# %%
sns.pairplot(data[['sepal length','sepal width','petal length','petal width','species']],hue = 'species')
